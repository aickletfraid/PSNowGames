# %%
import requests
import json
import html
from html2json import collect
from bs4 import BeautifulSoup
from bs2json import bs2json
import csv
import ast
import time
import unicodedata

# US
url = "https://www.playstation.com/en-us/explore/playstation-now/games/"

payload = {}
headers = {
  'authority': 'www.playstation.com',
  'cache-control': 'max-age=0',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-user': '?1',
  'sec-fetch-dest': 'document',
  'referer': 'https://www.playstation.com/en-us/explore/playstation-now/?smcid=pdc%3Aen-us%3Anetwork-store%3Aprimary%2520nav%3Amsg-services%3Aps-now',
  'accept-language': 'de-DE,de;q=0.9,ja-JP;q=0.8,ja;q=0.7,en-US;q=0.6,en;q=0.5,fr;q=0.4',
  'cookie': 'AKA_A2=A; sat_track=true; check=true; at_check=true; AMCVS_BD260C0F53C9733E0A490D45%40AdobeOrg=1; psvisitM=w; s_ecid=MCMID%7C64190044543703684361397487015065795629; mboxEdgeCluster=35; s_cc=true; AMCV_BD260C0F53C9733E0A490D45%40AdobeOrg=-408604571%7CMCIDTS%7C18418%7CMCMID%7C64190044543703684361397487015065795629%7CMCAAMLH-1591887612%7C6%7CMCAAMB-1591887612%7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y%7CMCOPTOUT-1591290017s%7CNONE%7CMCAID%7CNONE%7CMCSYNCSOP%7C411-18425%7CvVersion%7C4.6.0; sbPlatformPrivacyLevel=minimal; s_fid=67827CAEBEBE6BF2-39AB96BCE688D504; ps-utid=pdc%253Aen-us%253Anetwork-store%253Aprimary%252520nav%253Amsg-services%253Aps-now; ps-utparam=smcid; mbox=session#d3ccddd3f0c247bfb8e9626a9cf8762a#1591284744|PC#d3ccddd3f0c247bfb8e9626a9cf8762a.35_0#1654527619; JSESSIONID=node0hnzykseaumpk6w4age3vvus8261095.node0; s_sq=%5B%5BB%5D%5D',
  'connection':'close'
}
with requests.Session() as response:
    response = requests.request("GET", url, headers=headers, data = payload)
r = response.text.encode('utf8')
response.close()

soup = BeautifulSoup(r, "lxml")
converter = bs2json()
usgames = []
# print(soup.find('li',class_='game-title'))
allgames = []

region = 'US'
for s in soup.findAll('li', class_='game-title'):
        m = s.extract()
        extracter = converter.convert(m)
        gametitle = extracter['li']['text']
        console = 'unknown'
        game = [gametitle, console, region]
#         print(gametitle)
        usgames.append(game)


    
with open('psnowgamelist3-1.csv', mode='r',encoding="utf-8") as europe_file:
    csv_reader = csv.reader(europe_file, delimiter=',')
    for row in csv_reader:
#         print(row)
        included = 0
        for l in usgames:
#             print(l[0])
            importgame = ''.join(e for e in str(row[0]) if e.isalnum()).upper()
#             print(importgame)
            usgame = ''.join(f for f in str(l[0]) if f.isalnum()).upper()
#             print(usgame)
            if importgame == usgame:
                allgames.append([row[0],row[1],'yes','yes'])
                l.append(True)
                print(l)
                included = 1
        if included == 0:
            allgames.append([row[0],row[1],'yes', 'no'])
            
# for i in allgames:
#     print(i)
for l in usgames:
    if len(l)==3:
        allgames.append([l[0],l[1],'no','yes'])
            
with open('psnowgamelist3-2.csv', mode='w', encoding="utf-8", newline='') as gamelist_file:
    fieldname = ['Game', 'Console', 'Until', 'Europe', 'US']
    gamelist = csv.DictWriter(gamelist_file, fieldnames=fieldname)
    gamelist.writeheader()
    
    for i in allgames:
        gametitle = unicodedata.normalize("NFKD", i[0])
        if gametitle != " ":
            console = i[1]
            europe = i[2]
            us = i[3]
            gamelist.writerow({'Game': gametitle,'Console': console, 'Until': 'TBD', 'Europe': europe, 'US': us})
# Out:
# ['detuned', 'unknown', 'US', True]
# ['A Boy and His Blob', 'unknown', 'US', True]
# ['ABZU', 'unknown', 'US', True]
# ['Aces of the Luftwaffe', 'unknown', 'US', True]
# ['Act It Out! A Game Of Charades', 'unknown', 'US', True]
# ['Adventure Time: Pirates of the Enchiridion', 'unknown', 'US', True]
# ['Agatha Christie - The ABC Murders', 'unknown', 'US', True]
# ['Air Conflicts: Vietnam Ultimate Edition', 'unknown', 'US', True]
# ['Air Conflicts: Pacific Carriers', 'unknown', 'US', True]
# ['Alchemic Jousts', 'unknown', 'US', True]
# ['Alien Rage', 'unknown', 'US', True]
# ['Alien Rage', 'unknown', 'US', True, True]
# ['Alien Spidy', 'unknown', 'US', True]
# ['Alien Spidy', 'unknown', 'US', True, True]
# ['Alienation', 'unknown', 'US', True]
# ['Altered Beast', 'unknown', 'US', True]
# ['Altered Beast', 'unknown', 'US', True, True]
# ['Amazing Discoveries in Outer Space', 'unknown', 'US', True]
# ['Anarchy: Rush Hour', 'unknown', 'US', True]
# ['Anarchy: Rush Hour', 'unknown', 'US', True, True]
# ['Anna Extended Edition', 'unknown', 'US', True]
# ['Anna Extended Edition', 'unknown', 'US', True, True]
# ['Anodyne', 'unknown', 'US', True]
# ['Anomaly 2', 'unknown', 'US', True]
# ['Anomaly Warzone Earth', 'unknown', 'US', True]
# ['Aqua Panic!', 'unknown', 'US', True]
# ['Aqua Panic!', 'unknown', 'US', True, True]
# ['Ar Nosurge: Ode to an Unborn Star', 'unknown', 'US', True]
# ['Ar Nosurge: Ode to an Unborn Star', 'unknown', 'US', True, True]
# ['Aragami', 'unknown', 'US', True]
# ['Arcana Heart 3', 'unknown', 'US', True]
# ['Arcana Heart 3', 'unknown', 'US', True, True]
# ['ArcaniA - The Complete Tale', 'unknown', 'US', True]
# ['ArcaniA - The Complete Tale', 'unknown', 'US', True, True]
# ['Armageddon Riders', 'unknown', 'US', True]
# ['Armageddon Riders', 'unknown', 'US', True, True]
# ['Assault Suit Leynos', 'unknown', 'US', True]
# ['Assetto Corsa', 'unknown', 'US', True]
# ["Asura's Wrath", 'unknown', 'US', True]
# ["Asura's Wrath", 'unknown', 'US', True, True]
# ['Atari Flashback Classics Vol 1', 'unknown', 'US', True]
# ['Atari Flashback Classics Vol 2', 'unknown', 'US', True]
# ['Atelier Shallie: Alchemists of the Dusk Sea', 'unknown', 'US', True]
# ['Atelier Shallie: Alchemists of the Dusk Sea', 'unknown', 'US', True, True]
# ['Back to Bed', 'unknown', 'US', True]
# ['Bard’s Gold', 'unknown', 'US', True]
# ['Baseball Riot', 'unknown', 'US', True]
# ['Batman: Arkham City', 'unknown', 'US', True]
# ['Batman: Arkham Origins', 'unknown', 'US', True]
# ['Battalion Commander', 'unknown', 'US', True]
# ['Battle Chasers: Nightwar', 'unknown', 'US', True]
# ['Battle Princess of Arcadias', 'unknown', 'US', True]
# ['Battle Worlds: Kronos', 'unknown', 'US', True]
# ['Battlefield 4', 'unknown', 'US', True]
# ['Ben 10', 'unknown', 'US', True]
# ["Bentley's Hackpack", 'unknown', 'US', True]
# ['Big Sky: Infinity', 'unknown', 'US', True]
# ['Bionic Commando: Rearmed', 'unknown', 'US', True]
# ['Bionic Commando: Rearmed 2', 'unknown', 'US', True]
# ['Bioshock', 'unknown', 'US', True]
# ['BioShock 2', 'unknown', 'US', True]
# ['BioShock Infinite', 'unknown', 'US', True]
# ['Black Knight Sword', 'unknown', 'US', True]
# ['Black Mirror', 'unknown', 'US', True]
# ['Bladestorm: Nightmare', 'unknown', 'US', True]
# ['Bladestorm: The Hundred Years War', 'unknown', 'US', True]
# ['BlazBlue: Calamity Trigger', 'unknown', 'US', True]
# ['BlazBlue: Chrono Phantasma', 'unknown', 'US', True]
# ['BlazBlue: Chrono Phantasma EXTEND', 'unknown', 'US', True]
# ['BlazBlue: Continuum Shift Extend', 'unknown', 'US', True]
# ['BlazeRush', 'unknown', 'US', True]
# ['Blood Bowl 2', 'unknown', 'US', True]
# ['Blood Knights', 'unknown', 'US', True]
# ['Bloodborne', 'unknown', 'US', True]
# ['Bodycount', 'unknown', 'US', True]
# ['Bokosuka Wars II', 'unknown', 'US', True]
# ['Bolt', 'unknown', 'US', True]
# ['Bomberman Ultra', 'unknown', 'US', True]
# ['Borderlands: The Handsome Collection', 'unknown', 'US', True]
# ['Bound', 'unknown', 'US', True]
# ['Bound by Flame', 'unknown', 'US', True]
# ['Braid', 'unknown', 'US', True]
# ['Brawlout', 'unknown', 'US', True]
# ['Brink', 'unknown', 'US', True]
# ['Broken Age', 'unknown', 'US', True]
# ['Brothers: A Tale of Two Sons', 'unknown', 'US', True]
# ['BRUT@L', 'unknown', 'US', True]
# ['Bubsy: The Woolies Strike Back', 'unknown', 'US', True]
# ['Carmageddon: Max Damage', 'unknown', 'US', True]
# ['Cars Race-O-Rama', 'unknown', 'US', True]
# ['Castle Invasion: Throne Out', 'unknown', 'US', True]
# ['Castlevania Lords of Shadow', 'unknown', 'US', True]
# ['Castlevania Lords of Shadow - Mirror of Fate HD', 'unknown', 'US', True]
# ['Castlevania Lords of Shadow 2', 'unknown', 'US', True]
# ['Catherine', 'unknown', 'US', True]
# ['Cel Damage HD', 'unknown', 'US', True]
# ['Champion Jockey: G1 Jockey & Gallop Racer', 'unknown', 'US', True]
# ['Chess Ultra', 'unknown', 'US', True]
# ['Chronicles of Teddy: Harmony of Exidus', 'unknown', 'US', True]
# ['Cities: Skylines', 'unknown', 'US', True]
# ['Clockwork Tales: Of Glass and Ink', 'unknown', 'US', True]
# ['Clouds & Sheep 2', 'unknown', 'US', True]
# ['Control', 'unknown', 'US', True]
# ['Costume Quest 2', 'unknown', 'US', True]
# ['Counter Spy', 'unknown', 'US', True]
# ['Crash Commando', 'unknown', 'US', True]
# ['Crazy Taxi', 'unknown', 'US', True]
# ['Crimsonland', 'unknown', 'US', True]
# ['Critter Crunch', 'unknown', 'US', True]
# ['Croixleur Sigma', 'unknown', 'US', True]
# ['Damnation', 'unknown', 'US', True]
# ['Dandara', 'unknown', 'US', True]
# ['Danger Zone', 'unknown', 'US', True]
# ['Dangerous Golf', 'unknown', 'US', True]
# ['DARK ARCANA: THE CARNIVAL', 'unknown', 'US', True]
# ['Dark Void', 'unknown', 'US', True]
# ['Darksiders: Warmastered Edition', 'unknown', 'US', True]
# ['Darkstalkers Resurrection', 'unknown', 'US', True]
# ['Day of the Tentacle Remastered', 'unknown', 'US', True]
# ['de Blob', 'unknown', 'US', True]
# ['de Blob 2', 'unknown', 'US', True]
# ['Dead Island: Definitive Edition', 'unknown', 'US', True]
# ['Dead Island Retro Revenge', 'unknown', 'US', True]
# ['Dead Island Riptide', 'unknown', 'US', True]
# ['Dead Nation: Apocalypse Edition', 'unknown', 'US', True]
# ['Dead or Alive 5: Last Round', 'unknown', 'US', True]
# ['Dead Space 3', 'unknown', 'US', True]
# ["Deadlight Director's Cut", 'unknown', 'US', True]
# ['Death Track: Resurrection', 'unknown', 'US', True]
# ['Deception IV: Blood Ties', 'unknown', 'US', True]
# ['Defense Grid 2', 'unknown', 'US', True]
# ['Desert Child', 'unknown', 'US', True]
# ['Devil May Cry 4', 'unknown', 'US', True]
# ['Devil May Cry HD Collection', 'unknown', 'US', True]
# ['DiRT 4', 'unknown', 'US', True]
# ['DiRT Rally', 'unknown', 'US', True]
# ['Disgaea 3: Absence of Justice', 'unknown', 'US', True]
# ['Disgaea 4: A Promise Unforgotten', 'unknown', 'US', True]
# ['Disgaea 5: Alliance of Vengeance', 'unknown', 'US', True]
# ['Disgaea D2: A Brighter Darkness', 'unknown', 'US', True]
# ['Dishonored', 'unknown', 'US', True]
# ['Dishonored 2', 'unknown', 'US', True]
# ['Doki-Doki Universe', 'unknown', 'US', True]
# ['Don Bradman Cricket 14', 'unknown', 'US', True]
# ['Doom', 'unknown', 'US', True]
# ['Double Dragon Neon', 'unknown', 'US', True]
# ['Dungeons 2', 'unknown', 'US', True]
# ['Dynamite Fishing World Games', 'unknown', 'US', True]
# ['Dynasty Warriors 6: Empires', 'unknown', 'US', True]
# ['Dynasty Warriors 7', 'unknown', 'US', True]
# ['Dynasty Warriors 7: Empires', 'unknown', 'US', True]
# ['Dynasty Warriors 7: Xtreme Legends', 'unknown', 'US', True]
# ['Dynasty Warriors 8', 'unknown', 'US', True]
# ['Dynasty Warriors 8 Xtreme Legends', 'unknown', 'US', True]
# ['Dynasty Warriors: Strikeforce', 'unknown', 'US', True]
# ['Eat Them!', 'unknown', 'US', True]
# ['echochrome', 'unknown', 'US', True]
# ['Electronic Super Joy', 'unknown', 'US', True]
# ['Elefunk', 'unknown', 'US', True]
# ['Enigmatis: The Ghosts of Maple Creek', 'unknown', 'US', True]
# ['Entwined', 'unknown', 'US', True]
# ['Escape Plan', 'unknown', 'US', True]
# ['Ethan: Meteor Hunter', 'unknown', 'US', True]
# ['Eufloria', 'unknown', 'US', True]
# ["Everybody's Gone to the Rapture", 'unknown', 'US', True]
# ['Exile’s End', 'unknown', 'US', True]
# ['Exist Archive: The Other Side of the Sky', 'unknown', 'US', True]
# ['Extreme Exorcism', 'unknown', 'US', True]
# ['F1 2014', 'unknown', 'US', True]
# ['F1 2015', 'unknown', 'US', True]
# ['F1 2016', 'unknown', 'US', True]
# ['F1 2017', 'unknown', 'US', True]
# ['F1 2019', 'unknown', 'US', True]
# ['F1 RACE STARS', 'unknown', 'US', True]
# ['Faery: Legends of Avalon', 'unknown', 'US', True]
# ['Fairy Fencer F: Advent Dark Force', 'unknown', 'US', True]
# ['Fallout 3', 'unknown', 'US', True]
# ['Fallout 4', 'unknown', 'US', True]
# ['Fallout New Vegas', 'unknown', 'US', True]
# ['Farming Simulator 19', 'unknown', 'US', True]
# ['Fighting Vipers', 'unknown', 'US', True]
# ['Final Exam', 'unknown', 'US', True]
# ['Final Fight: Double Impact', 'unknown', 'US', True]
# ['fLOW', 'unknown', 'US', True]
# ['Flower', 'unknown', 'US', True]
# ['Fluster Cluck', 'unknown', 'US', True]
# ['For Honor', 'unknown', 'US', True]
# ['Frogger Returns', 'unknown', 'US', True]
# ['G-Force', 'unknown', 'US', True]
# ['Gal*Gun: Double Peace', 'unknown', 'US', True]
# ['Garou: Mark of the Wolves', 'unknown', 'US', True]
# ['Gem Smashers', 'unknown', 'US', True]
# ['Get Even', 'unknown', 'US', True]
# ['Go! Puzzle', 'unknown', 'US', True]
# ['God Eater 2: Rage Burst', 'unknown', 'US', True]
# ['God of War HD', 'unknown', 'US', True]
# ['God of War: Ascension', 'unknown', 'US', True]
# ['God of War: Chains of Olympus', 'unknown', 'US', True]
# ['Golden Axe', 'unknown', 'US', True]
# ['Grand Ages: Medieval', 'unknown', 'US', True]
# ['Grand Kingdom', 'unknown', 'US', True]
# ['Gravity Crash', 'unknown', 'US', True]
# ['Gravity Rush 2', 'unknown', 'US', True]
# ['Gravity Rush Remastered', 'unknown', 'US', True]
# ['Greg Hastings Paintball 2', 'unknown', 'US', True]
# ['Grid 2', 'unknown', 'US', True]
# ['Grid Autosport', 'unknown', 'US', True]
# ['Grim Fandango Remastered', 'unknown', 'US', True]
# ['Guacamelee!', 'unknown', 'US', True]
# ['Guilty Gear Xrd -Revelator', 'unknown', 'US', True]
# ['Hakuoki: Stories of the Shinsengumi', 'unknown', 'US', True]
# ["Hamilton's Great Adventure", 'unknown', 'US', True]
# ['Hamsterball', 'unknown', 'US', True]
# ['Hardware Rivals', 'unknown', 'US', True]
# ['Heavenly Sword', 'unknown', 'US', True]
# ['Heavy Fire: Afghanistan', 'unknown', 'US', True]
# ['Hohokum', 'unknown', 'US', True]
# ['Hollow Knight', 'unknown', 'US', True]
# ['Hotel Transylvania 3 Monsters Overboard', 'unknown', 'US', True]
# ["Hunted: The Demon's Forge", 'unknown', 'US', True]
# ['Hunter’s Trophy 2: America', 'unknown', 'US', True]
# ['Hunter’s Trophy 2 : Australia', 'unknown', 'US', True]
# ['Hustle Kings', 'unknown', 'US', True]
# ['I Am Bread', 'unknown', 'US', True]
# ['ibb & obb', 'unknown', 'US', True]
# ['In Space We Brawl', 'unknown', 'US', True]
# ['inFAMOUS', 'unknown', 'US', True]
# ['inFAMOUS 2', 'unknown', 'US', True]
# ['inFAMOUS: Festival Of Blood', 'unknown', 'US', True]
# ['Inside My Radio', 'unknown', 'US', True]
# ['Invizimals: The Lost Kingdom', 'unknown', 'US', True]
# ['Ironcast', 'unknown', 'US', True]
# ['Jetpack Joyride Deluxe', 'unknown', 'US', True]
# ['Joe Danger 2: The Movie', 'unknown', 'US', True]
# ["Joe Dever's Lone Wolf", 'unknown', 'US', True]
# ['Journey', 'unknown', 'US', True]
# ['Judge Dee - The City God Case', 'unknown', 'US', True]
# ['Killzone 2', 'unknown', 'US', True]
# ['Killzone 3', 'unknown', 'US', True]
# ['Killzone Shadow Fall', 'unknown', 'US', True]
# ['King Oddball', 'unknown', 'US', True]
# ['Kingdom: New Lands', 'unknown', 'US', True]
# ['Knack', 'unknown', 'US', True]
# ['Knytt Underground', 'unknown', 'US', True]
# ['Kung Fu Rabbit', 'unknown', 'US', True]
# ['Legasista', 'unknown', 'US', True]
# ['Legend of Kay Anniversary', 'unknown', 'US', True]
# ['LEGO Batman 2: DC Super Heroes', 'unknown', 'US', True]
# ['LEGO Batman 3: Beyond Gotham', 'unknown', 'US', True]
# ['LEGO Batman: The Videogame', 'unknown', 'US', True]
# ['LEGO Harry Potter: Years 1-4', 'unknown', 'US', True]
# ['LEGO Harry Potter: Years 5-7', 'unknown', 'US', True]
# ['LEGO Worlds', 'unknown', 'US', True]
# ['Lemmings', 'unknown', 'US', True]
# ["Leo's Fortune", 'unknown', 'US', True]
# ['Limbo', 'unknown', 'US', True]
# ['Linger in Shadows', 'unknown', 'US', True]
# ['LittleBigPlanet 3', 'unknown', 'US', True]
# ['LittleBigPlanet 3', 'unknown', 'US', True, True]
# ['Lock’s Quest', 'unknown', 'US', True]
# ['LocoRoco Cocoreccho!', 'unknown', 'US', True]
# ['LocoRoco Remastered', 'unknown', 'US', True]
# ["Lone Survivor: The Director's Cut", 'unknown', 'US', True]
# ['Lords of the Fallen', 'unknown', 'US', True]
# ['Lost Planet 2', 'unknown', 'US', True]
# ['Lost Planet 3', 'unknown', 'US', True]
# ['Lost Sea', 'unknown', 'US', True]
# ['Lovely Planet', 'unknown', 'US', True]
# ['Machinarium', 'unknown', 'US', True]
# ['Mafia III', 'unknown', 'US', True]
# ['Magic Orbz', 'unknown', 'US', True]
# ['Magicka 2', 'unknown', 'US', True]
# ['Magus', 'unknown', 'US', True]
# ['Mahjong Tales™: Ancient Wisdom', 'unknown', 'US', True]
# ['Malicious Fallen', 'unknown', 'US', True]
# ['Mantis Burn Racing', 'unknown', 'US', True]
# ['Mars: War Logs', 'unknown', 'US', True]
# ["Marvel's Spider-Man", 'unknown', 'US', True]
# ['Mastercube', 'unknown', 'US', True]
# ['Mega Man 10', 'unknown', 'US', True]
# ['Mega Man 9', 'unknown', 'US', True]
# ['Megadimension Neptunia VII', 'unknown', 'US', True]
# ['Metal Gear Solid HD Collection', 'unknown', 'US', True]
# ['Metal Gear Solid V: The Phantom Pain', 'unknown', 'US', True]
# ['Metal Slug 3', 'unknown', 'US', True]
# ['Metro Exodus', 'unknown', 'US', True]
# ['Metro Last Light Redux', 'unknown', 'US', True]
# ['Minutes', 'unknown', 'US', True]
# ['Mirror’s Edge', 'unknown', 'US', True]
# ['Mitsurugi Kamui Hikae', 'unknown', 'US', True]
# ['Momonga Pinball Adventures', 'unknown', 'US', True]
# ['Mordheim - City of the Damned', 'unknown', 'US', True]
# ['MotoGP 17', 'unknown', 'US', True]
# ['Motorcycle Club', 'unknown', 'US', True]
# ['MotorStorm: Apocalypse', 'unknown', 'US', True]
# ['Motorstorm RC Complete Edition', 'unknown', 'US', True]
# ['Mount & Blade: Warband', 'unknown', 'US', True]
# ['MouseCraft', 'unknown', 'US', True]
# ['Mudrunner', 'unknown', 'US', True]
# ['MX vs ATV Supercross Encore', 'unknown', 'US', True]
# ['MX vs. ATV Alive', 'unknown', 'US', True]
# ['MX vs. ATV: Untamed', 'unknown', 'US', True]
# ['MX vs. ATV Reflex', 'unknown', 'US', True]
# ['MXGP 2 - The Official Motocross Videogame', 'unknown', 'US', True]
# ['MXGP3 – The Official Motocross Videogame', 'unknown', 'US', True]
# ['Mystery Chronicle: One Way Heroics', 'unknown', 'US', True]
# ['Nascar Heat 3', 'unknown', 'US', True]
# ['Nascar Heat 4', 'unknown', 'US', True]
# ['Natural Doctrine', 'unknown', 'US', True]
# ['NBA 2K18', 'unknown', 'US', True]
# ['Need for Speed Rivals', 'unknown', 'US', True]
# ['Neon Chrome', 'unknown', 'US', True]
# ['Neurovoider', 'unknown', 'US', True]
# ['Nidhogg', 'unknown', 'US', True]
# ['NIGHTMARES FROM THE DEEP 2: THE SIREN`S CALL', 'unknown', 'US', True]
# ['Nights Into Dreams', 'unknown', 'US', True]
# ['Nights of Azure', 'unknown', 'US', True]
# ['Nights of Azure 2: Bride of the New Moon', 'unknown', 'US', True]
# ["Ninja Gaiden 3: Razor's Edge", 'unknown', 'US', True]
# ['Ninja Gaiden Sigma 2', 'unknown', 'US', True]
# ['No Time to Explain', 'unknown', 'US', True]
# ["Nobunaga's Ambition: Sphere of Influence", 'unknown', 'US', True]
# ['Nom Nom Galaxy', 'unknown', 'US', True]
# ['NOVA-111', 'unknown', 'US', True]
# ['Numblast', 'unknown', 'US', True]
# ['Obliteracers', 'unknown', 'US', True]
# ["Oddworld: Stranger's Wrath HD", 'unknown', 'US', True]
# ['OlliOlli', 'unknown', 'US', True]
# ['Omega Quintet', 'unknown', 'US', True]
# ['Operation Flashpoint: Dragon Rising', 'unknown', 'US', True]
# ['Operation Flashpoint: Red River', 'unknown', 'US', True]
# ['Overcooked! 2', 'unknown', 'US', True]
# ['Overlord: Raising Hell', 'unknown', 'US', True]
# ['Overlord: Fellowship of Evil', 'unknown', 'US', True]
# ['Pac-Man Championship Edition 2', 'unknown', 'US', True]
# ['Painkiller: Hell & Damnation', 'unknown', 'US', True]
# ['Papo & Yo', 'unknown', 'US', True]
# ['Pillars of Eternity: Complete Edition', 'unknown', 'US', True]
# ["Pirates of the Caribbean: At World's End", 'unknown', 'US', True]
# ['Pixel Heroes: Byte & Magic', 'unknown', 'US', True]
# ['Pixel Piracy', 'unknown', 'US', True]
# ['PixelJunk Racers 2nd Lap', 'unknown', 'US', True]
# ['PixelJunk Shooter', 'unknown', 'US', True]
# ['PixelJunk Shooter 2', 'unknown', 'US', True]
# ['PixelJunk Shooter Ultimate', 'unknown', 'US', True]
# ['PixelJunk Sidescroller', 'unknown', 'US', True]
# ['Piyotama', 'unknown', 'US', True]
# ['Plague Road', 'unknown', 'US', True]
# ['Planet Minigolf', 'unknown', 'US', True]
# ['Planets Under Attack', 'unknown', 'US', True]
# ["PlayerUnknown's Battlegrounds", 'unknown', 'US', True]
# ['Poncho', 'unknown', 'US', True]
# ['Pool Nation', 'unknown', 'US', True]
# ['Prey', 'unknown', 'US', True]
# ['Proteus', 'unknown', 'US', True]
# ['Pumped BMX+', 'unknown', 'US', True]
# ['Puppeteer', 'unknown', 'US', True]
# ["Pure Hold'em World Poker Championship", 'unknown', 'US', True]
# ['Pure Pool', 'unknown', 'US', True]
# ['Puzzle Agent', 'unknown', 'US', True]
# ['Q*Bert: Rebooted', 'unknown', 'US', True]
# ['Quantum Theory', 'unknown', 'US', True]
# ['R-Type Dimensions', 'unknown', 'US', True]
# ['Rad Rodgers', 'unknown', 'US', True]
# ['Rage', 'unknown', 'US', True]
# ['Ragnarok Odyssey Ace', 'unknown', 'US', True]
# ['Raiden IV Overkill', 'unknown', 'US', True]
# ['Raiden V: Director’s Cut', 'unknown', 'US', True]
# ['Rain', 'unknown', 'US', True]
# ['Rainbow Moon', 'unknown', 'US', True]
# ['Rapala Fishing: Pro Series', 'unknown', 'US', True]
# ['Ratatouille', 'unknown', 'US', True]
# ['Ratchet & Clank: All 4 One', 'unknown', 'US', True]
# ['Ratchet & Clank: A Crack in Time', 'unknown', 'US', True]
# ['Ratchet & Clank: Quest for Booty', 'unknown', 'US', True]
# ['Real Farm', 'unknown', 'US', True]
# ['Realms of Ancient War', 'unknown', 'US', True]
# ['Rebel Galaxy', 'unknown', 'US', True]
# ['Red Dead Redemption', 'unknown', 'US', True]
# ['Red Dead Redemption: Undead Nightmare', 'unknown', 'US', True]
# ['Red Johnson’s Chronicles: One Against All', 'unknown', 'US', True]
# ['Renegade Ops', 'unknown', 'US', True]
# ['Resident Evil Operation Raccoon City', 'unknown', 'US', True]
# ['Resident Evil Revelations', 'unknown', 'US', True]
# ['Resistance 3', 'unknown', 'US', True]
# ['Resogun', 'unknown', 'US', True]
# ['Retro City Rampage DX', 'unknown', 'US', True]
# ['Retrograde', 'unknown', 'US', True]
# ['Reus', 'unknown', 'US', True]
# ['Ricochet HD', 'unknown', 'US', True]
# ['RIDE 3', 'unknown', 'US', True]
# ['Rise of the Argonauts', 'unknown', 'US', True]
# ['RIVE', 'unknown', 'US', True]
# ['Rocket League', 'unknown', 'US', True]
# ['Rocketbirds: Hardboiled Chicken', 'unknown', 'US', True]
# ['Rogue Stormers', 'unknown', 'US', True]
# ['Romance of the Three Kingdoms 13', 'unknown', 'US', True]
# ['Rotastic', 'unknown', 'US', True]
# ['Sacred Citadel', 'unknown', 'US', True]
# ['Saints Row 2', 'unknown', 'US', True]
# ['Saints Row: Gat Out of Hell', 'unknown', 'US', True]
# ['Saints Row IV: Re-Elected', 'unknown', 'US', True]
# ['Samurai Warriors 4', 'unknown', 'US', True]
# ['Savage Moon', 'unknown', 'US', True]
# ['Seasons After Fall', 'unknown', 'US', True]
# ['Shadow of the Beast', 'unknown', 'US', True]
# ['Shadow of the Tomb Raider', 'unknown', 'US', True]
# ['Shadwen', 'unknown', 'US', True]
# ['Shatter', 'unknown', 'US', True]
# ["Sherlock Holmes: The Devil's Daughter", 'unknown', 'US', True]
# ['Shiness: The Lightning Kingdom', 'unknown', 'US', True]
# ['Sid Meier’s Civilization Revolution', 'unknown', 'US', True]
# ['Silent Hill HD Collection', 'unknown', 'US', True]
# ['Sine Mora EX', 'unknown', 'US', True]
# ['Skullgirls Encore', 'unknown', 'US', True]
# ['Sky Fighter', 'unknown', 'US', True]
# ['Sky Dive: Proximity Flight', 'unknown', 'US', True]
# ['Skyscrappers', 'unknown', 'US', True]
# ['Slime-san Superslime Edition', 'unknown', 'US', True]
# ['Sly Cooper: Thieves in Time', 'unknown', 'US', True]
# ['Smash Cars', 'unknown', 'US', True]
# ['Snakeball', 'unknown', 'US', True]
# ['Sniper Elite 4', 'unknown', 'US', True]
# ['Sniper Elite V2', 'unknown', 'US', True]
# ['Sniper: Ghost Warrior 2', 'unknown', 'US', True]
# ['Sniper: Ghost Warrior', 'unknown', 'US', True]
# ['Soldner-X 2: Final Prototype', 'unknown', 'US', True]
# ['Soldner-X: Himmelssturmer', 'unknown', 'US', True]
# ['SOMA', 'unknown', 'US', True]
# ['Sonic Adventure', 'unknown', 'US', True]
# ['Sonic Adventure 2', 'unknown', 'US', True]
# ['Sonic CD', 'unknown', 'US', True]
# ['Sonic Generations', 'unknown', 'US', True]
# ['Sonic the Fighters', 'unknown', 'US', True]
# ['Sonic The Hedgehog 4 Episode II', 'unknown', 'US', True]
# ['Sonic Unleashed', 'unknown', 'US', True]
# ['Soul Axiom', 'unknown', 'US', True]
# ['Sound Shapes', 'unknown', 'US', True]
# ['Space Ace', 'unknown', 'US', True]
# ['Sparkle 2', 'unknown', 'US', True]
# ['Sparkle Unleashed', 'unknown', 'US', True]
# ['Spec Ops: The Line', 'unknown', 'US', True]
# ['Spelunky', 'unknown', 'US', True]
# ['Square Heroes', 'unknown', 'US', True]
# ['Starhawk', 'unknown', 'US', True]
# ['Starwhal', 'unknown', 'US', True]
# ['Steep', 'unknown', 'US', True]
# ['Stick it to the Man', 'unknown', 'US', True]
# ['Stikbold! A Dodgeball Adventure', 'unknown', 'US', True]
# ['Strider', 'unknown', 'US', True]
# ["Strike Suit Zero: Director's Cut", 'unknown', 'US', True]
# ['Styx: Shards of Darkness', 'unknown', 'US', True]
# ['Super Hang-On', 'unknown', 'US', True]
# ['Super Mega Baseball', 'unknown', 'US', True]
# ['Super Puzzle Fighter II Turbo HD Remix', 'unknown', 'US', True]
# ['Super Star Wars', 'unknown', 'US', True]
# ['Super Toy Cars', 'unknown', 'US', True]
# ['Syberia', 'unknown', 'US', True]
# ['Sebastien Loeb Rally Evo', 'unknown', 'US', True]
# ['Tachyon Project', 'unknown', 'US', True]
# ['Tales from Space: About a Blob', 'unknown', 'US', True]
# ['Tales from Space: Mutant Blobs Attack', 'unknown', 'US', True]
# ['Tales of Zestiria', 'unknown', 'US', True]
# ['Tearaway Unfolded', 'unknown', 'US', True]
# ['Tennis in the Face', 'unknown', 'US', True]
# ['Terraria', 'unknown', 'US', True]
# ['Tetraminos', 'unknown', 'US', True]
# ['The Awakened Fate Ultimatum', 'unknown', 'US', True]
# ['The Book of Unwritten Tales 2', 'unknown', 'US', True]
# ['The Bug Butcher', 'unknown', 'US', True]
# ['The Darkness', 'unknown', 'US', True]
# ['The Dwarves', 'unknown', 'US', True]
# ['The Evil Within', 'unknown', 'US', True]
# ['The Evil Within 2', 'unknown', 'US', True]
# ['The Final Station', 'unknown', 'US', True]
# ['The Guided Fate Paradox', 'unknown', 'US', True]
# ['The House of the Dead 3', 'unknown', 'US', True]
# ['The House of the Dead Overkill Extended Cut', 'unknown', 'US', True]
# ['The Keeper of 4 Elements', 'unknown', 'US', True]
# ['The King of Fighters XIII', 'unknown', 'US', True]
# ['The Last Guy', 'unknown', 'US', True]
# ['The Last of Us', 'unknown', 'US', True]
# ['The Last of Us: Left Behind', 'unknown', 'US', True]
# ['The LEGO Movie Videogame', 'unknown', 'US', True]
# ['The Metronomicon: Slay the Dance Floor', 'unknown', 'US', True]
# ['The Raven Remastered', 'unknown', 'US', True]
# ['The Raven: Legacy of a Master Thief', 'unknown', 'US', True]
# ['The Spectrum Retreat', 'unknown', 'US', True]
# ['The Surge', 'unknown', 'US', True]
# ['The Swapper', 'unknown', 'US', True]
# ['The Swindle', 'unknown', 'US', True]
# ['The Vanishing of Ethan Carter', 'unknown', 'US', True]
# ['The Wolf Among Us', 'unknown', 'US', True]
# ['This War of Mine: The Little Ones', 'unknown', 'US', True]
# ['Thomas was Alone', 'unknown', 'US', True]
# ['Titan Quest', 'unknown', 'US', True]
# ['Tokyo Jungle', 'unknown', 'US', True]
# ["Tom Clancy's Rainbow Six Siege", 'unknown', 'US', True]
# ['Touhou: Scarlet Curiosity', 'unknown', 'US', True]
# ['Toukiden 2', 'unknown', 'US', True]
# ['Toukiden: Kiwami', 'unknown', 'US', True]
# ['Toy Home', 'unknown', 'US', True]
# ['Toybox Turbos', 'unknown', 'US', True]
# ['Trash Panic', 'unknown', 'US', True]
# ['Tricky Towers', 'unknown', 'US', True]
# ['Trine', 'unknown', 'US', True]
# ["Trinity: Souls of Zill O'll", 'unknown', 'US', True]
# ['TRON: Evolution', 'unknown', 'US', True]
# ['TRON RUN/r', 'unknown', 'US', True]
# ['Tropico 5', 'unknown', 'US', True]
# ['Truck Racer', 'unknown', 'US', True]
# ['Twisted Metal', 'unknown', 'US', True]
# ['Ultra Street Fighter IV', 'unknown', 'US', True]
# ['Uncharted 2: Among Thieves', 'unknown', 'US', True]
# ["Uncharted 3: Drake's Deception - Game of the Year Edition", 'unknown', 'US', True]
# ['Uncharted: Drake’s Fortune', 'unknown', 'US', True]
# ['Until Dawn', 'unknown', 'US', True]
# ['Urban Trial FreeStyle', 'unknown', 'US', True]
# ['Vampyr', 'unknown', 'US', True]
# ['Vegas Party', 'unknown', 'US', True]
# ['Velocibox', 'unknown', 'US', True]
# ['Velocity 2X', 'unknown', 'US', True]
# ['Velocity Ultra', 'unknown', 'US', True]
# ['Vessel', 'unknown', 'US', True]
# ['Vikings: Wolves of Midgard', 'unknown', 'US', True]
# ['Virtua Fighter 2', 'unknown', 'US', True]
# ['Virtua Fighter 5: Final Showdown', 'unknown', 'US', True]
# ['Wakeboarding HD', 'unknown', 'US', True]
# ['Warriors All-Stars', 'unknown', 'US', True]
# ['Warriors Orochi 3', 'unknown', 'US', True]
# ['Warriors: Legends of Troy', 'unknown', 'US', True]
# ["Wasteland 2: Director's Cut", 'unknown', 'US', True]
# ['Wet', 'unknown', 'US', True]
# ['When Vikings Attack', 'unknown', 'US', True]
# ['Whispering Willows', 'unknown', 'US', True]
# ['White Knight Chronicles', 'unknown', 'US', True]
# ['Wild Guns Reloaded', 'unknown', 'US', True]
# ['Wolfenstein The New Order', 'unknown', 'US', True]
# ['Wolfenstein The New Order', 'unknown', 'US', True, True]
# ['Wolfenstein The Old Blood', 'unknown', 'US', True]
# ['World to the West', 'unknown', 'US', True]
# ['WRC 5: FIA World Rally Championship', 'unknown', 'US', True]
# ['Wuppo', 'unknown', 'US', True]
# ['WWE 2K18', 'unknown', 'US', True]
# ['XCOM 2', 'unknown', 'US', True]
# ['XCOM: Enemy Within', 'unknown', 'US', True]
# ['Yaiba: Ninja Gaiden Z', 'unknown', 'US', True]
# ['Yakuza 4', 'unknown', 'US', True]
# ['Yakuza 5', 'unknown', 'US', True]
# ['Zack Zero', 'unknown', 'US', True]
# ['Ziggurat', 'unknown', 'US', True]
# ['Zombie Vikings', 'unknown', 'US', True]

# %%
string = "Special $#! characters   spaces 888323"
print(''.join(e for e in string if e.isalnum()))
sdf = "Special $#! characters   spaceswedfserg 888323"
print(''.join(f for f in sdf if f.isalnum()))
# Out:
# Specialcharactersspaces888323
# Specialcharactersspaceswedfserg888323
