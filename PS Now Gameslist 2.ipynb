# %%
import requests
import json
import html
from html2json import collect
from bs4 import BeautifulSoup
from bs2json import bs2json
import csv
import ast
import time

with open('psnowgamelist.csv', mode='w', encoding="utf-8", newline='') as gamelist_file:
    fieldname = ['Game', 'Console', 'Until']
    gamelist = csv.DictWriter(gamelist_file, fieldnames=fieldname)
    gamelist.writeheader()
    url = "https://psvrtrophy.software.eu.playstation.com/ps-now/data_sync"

    headers = {
      'Connection': 'keep-alive',
      'Accept': 'application/json, text/javascript, */*; q=0.01',
      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36',
      'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
#       'Origin': 'https://www.playstation.com',
#       'Sec-Fetch-Site': 'same-site',
#       'Sec-Fetch-Mode': 'cors',
#       'Sec-Fetch-Dest': 'empty',
#       'Referer': 'https://www.playstation.com/de-de/explore/playstation-now/playstation-now-spiele-katalog/',
#       'Accept-Language': 'de-DE,de;q=0.9,ja-JP;q=0.8,ja;q=0.7,en-US;q=0.6,en;q=0.5,fr;q=0.4'
    }
    for i in range(0,99):
        payload = "genre=&platform=&sorting=alphabetical&search=&ajax_action=filter_games&page_num=" + str(i)
        try:
            response = requests.request("POST", url, headers=headers, data = payload)
        except requests.exceptions.RequestException as e:
            raise SystemExit(e)
        games = json.loads(response.text)
        if games['action_queue'][0][1]:
            games = games['action_queue'][0][1]['value']
            converter = bs2json()
            soup = BeautifulSoup(games, "lxml")

            for j in soup.findAll('div', class_="cc_psnow_game_item"):
                for s in j.findAll('h3'):
                    m = s.extract()
                    extracter = converter.convert(m)
                    gametitle = extracter['h3']['text']
                if j.find('img', alt="PS3"):
                    console = "PS3"
                elif j.find('img', alt="PS4"):
                    console = "PS4"
                elif j.find('img', alt="PS2"):
                    console = "PS2"
                print(gametitle+console)
                gamelist.writerow({'Game': gametitle,'Console': console, 'Until': 'TBD'})
# Out:
# ACT IT OUT! Ein ScharadespielPS4
# Action HenkPS4
# Agatha Christie - The ABC MurdersPS4
# Air Conflicts Vietnam Ultimate EditionPS4
# Air Conflicts: Pacific Carriers - PlayStation®4 EditionPS4
# Alchemic JoustsPS4
# Alex Kidd in Miracle World™PS3
# Alien Rage BundlePS3
# Alien SpidyPS3
# ALIENATION™PS4
# Altered BeastPS3
# Amazing Discoveries In Outer SpacePS4
# Anarchy: Rush HourPS3
# Anna – Extended EditionPS3
# AnodynePS4
# Anomaly 2PS4
# Anomaly Warzone EarthPS3
# Ape Escape 2PS2
# Aqua Panic!PS3
# Ar nosurge: Ode to an Unborn StarPS3
# AragamiPS4
# Arc the Lad: Twilight of the SpiritsPS2
# ArcaniA - The complete talePS3
# Armageddon RidersPS3
# Assault Suit LeynosPS4
# Assetto CorsaPS4
# Atari Flashback Classics Vol. 1PS4
# Atari Flashback Classics Vol. 2PS4
# Atelier Ayesha: The Alchemist of DuskPS3
# Atelier Escha and Logy  ~Alchemists of the Dusk Sky~PS3
# Atelier Rorona Plus: The Alchemist of ArlandPS3
# Atelier Shallie ~Alchemists of the Dusk Sea~PS3
# Back to Bed Game and Dynamic Theme BundlePS3
# Baja: Edge of Control HDPS4
# Bard's GoldPS4
# Baseball RiotPS4
# Batman - The Telltale Series - Episode 1: Realm of ShadowsPS4
# Batman: Arkham CityPS3
# Batman: Arkham KnightPS4
# Battalion CommanderPS4
# Battle Chasers: NightwarPS4
# Battle Princess of ArcadiasPS3
# Battle Worlds: KronosPS4
# Battlefield 4™PS3
# Ben 10PS4
# Bentleys Hack-Paket™PS3
# BEYOND: Two Souls™PS4
# BinariesPS4
# BIONIC COMMANDO REARMEDPS3
# Bionic Commando™ Rearmed 2PS3
# BioShock InfinitePS3
# Black MirrorPS4
# BLADESTORM: NightmarePS3
# Bladestorm: The Hundred Years' WarPS3
# Blast 'Em BunniesPS4
# BlazBlue Chronophantasma ExtendPS4
# BLAZBLUE　CHRONOPHANTASMAPS3
# BlazeRushPS3
# Blood Bowl 2PS4
# Blood KnightsPS3
# Bloodborne™PS4
# BloodRayne: BetrayalPS3
# BodycountPS3
# BOKOSUKA WARS IIPS4
# Bolt PS3™PS3
# BOMBERMAN ULTRAPS3
# Borderlands 2 Ultimate EditionPS3
# Borderlands: The Handsome CollectionPS4
# Bound by Flame™PS4
# Bound™PS4
# BraidPS3
# BrawloutPS4
# Broken AgePS4
# Brothers: a Tale of two SonsPS4
# Brut@lPS4
# Bubsy: The Woolies Strike BackPS4
# CAPCOM ARCADE CABINET: KOMPLETTPAKETPS3
# Castle Invasion: Throne OutPS4
# CastleStorm Definitive EditionPS4
# Castlevania: Harmony of DespairPS3
# CatherinePS3
# Champion Jockey: G1 Jockey and Gallop RacerPS3
# Chess UltraPS4
# Chronicles of Teddy: Harmony of ExidusPS4
# Cities: Skylines - PlayStation®4 EditionPS4
# Clockwork Tales: Of Glass and InkPS4
# Clouds and Sheep 2PS4
# Control Standard EditionPS4
# Costume Quest 2PS4
# CounterSpy™PS3
# Crash Commando™PS3
# Crazy TaxiPS3
# CrimsonlandPS4
# Critter CrunchPS3
# Croixleur SigmaPS4
# CuboidPS3
# Dandara: Trials of Fear EditionPS4
# Danger ZonePS4
# Dangerous Golf™PS4
# Dark Arcana: The CarnivalPS4
# Dark Chronicle™PS2
# Dark Cloud™PS2
# Dark Mist™PS3
# Darksiders II Deathinitive EditionPS4
# Darksiders Warmastered EditionPS4
# Darkstalkers™ ResurrectionPS3
# Day of the Tentacle RemasteredPS4
# Daytona USAPS3
# de BlobPS4
# de Blob 2PS3
# Dead Island Retro RevengePS4
# Dead Nation™: Apocalypse EditionPS4
# Dead or Alive 5 Ultimate Full Version UnlockPS3
# Dead Space™ 3PS3
# Deadlight: Director's CutPS4
# Deadly Premonition: Director's CutPS3
# Death Track: ResurrectionPS3
# Deception IV: Blood TiesPS3
# Deception IV: The Nightmare PrincessPS3
# Defense Grid 2PS4
# Der Puppenspieler™PS3
# Desert ChildPS4
# Destroy All Humans!PS2
# Devil May Cry® HD CollectionPS3
# DiRT 4PS4
# DiRT RallyPS4
# Disgaea D2: A Brighter DarknessPS3
# Dishonored: Die Maske des ZornsPS3
# Disney Universe Ultimate EditionPS3
# Disney · PIXAR Toy Story Mania!PS3
# Disney•Pixar Merida Legende der HighlandsPS3
# Doki-Doki Universe™PS4
# Don Bradman Cricket 14PS3
# Don't Die, Mr. Robot!PS4
# DOOMPS4
# Double Dragon Neon Full Game UpgradePS3
# Duke Nukem ForeverPS3
# Dungeons 2PS4
# Dynamite Fishing – World GamesPS4
# DYNASTY WARRIORS 6PS3
# Dynasty Warriors 6 EmpiresPS3
# Dynasty Warriors 7PS3
# DYNASTY WARRIORS 7 EmpiresPS3
# DYNASTY WARRIORS 7: Xtreme LegendsPS3
# Dynasty Warriors 8PS3
# Dynasty Warriors 8: Xtreme LegendsPS3
# Dynasty Warriors StrikeforcePS3
# Earth Defense Force 4.1: The Shadow of New DespairPS4
# EARTH'S DAWNPS4
# echochromePS3
# Electronic Super JoyPS4
# Elefunk™PS3
# Enigmatis 2: The Mists of RavenwoodPS4
# Enigmatis: The Ghosts of Maple CreekPS4
# Entwined™PS3
# Escape Plan™PS4
# Ethan: Meteor HunterPS3
# EufloriaPS3
# EVE: Valkyrie – WarzonePS4
# Eventide: Slavic FablePS4
# Everybody's Golf®PS3
# Everybody’s Gone to the Rapture™PS4
# Everybody’s TennisPS2
# Exile's EndPS4
# Exist Archive: The Other Side of the SkyPS4
# Extreme ExorcismPS3
# F1 RACE STARS™PS3
# F1® 2019PS4
# F1™ 2014PS3
# F1™ 2015PS4
# F1™ 2016PS4
# F1™ 2017PS4
# Faery: Legends of AvalonPS3
# Fairy Fencer F: Advent Dark ForcePS4
# Fallout 4PS4
# FantaVisionPS2
# Fat Princess™ AdventuresPS4
# Fighting VipersPS3
# Final ExamPS3
# Final Fight: Double ImpactPS3
# FlowerPS3
# flOw™PS3
# FLUSTER CLUCK™PS4
# FOR HONOR™ STANDARD EDITIONPS4
# Forbidden SirenPS2
# Frogger ReturnsPS3
# Gal*Gun: Double PeacePS4
# GAME OF YEAR EDITIONPS3
# GAROU: MARK OF THE WOLVES™PS4
# Gem SmashersPS4
# Get EvenPS4
# Giana Sisters: Twisted Dreams – Director’s CutPS4
# God of War III™PS3
# God of War: Ascension™PS3
# God of War® HDPS3
# God of War® II HDPS3
# God of War® III RemasteredPS4
# God of War®: Chains of OlympusPS3
# God of War®: Ghost of SpartaPS3
# Golden AxePS3
# Grand Ages: MedievalPS4
# Grand KingdomPS4
# Gravity Crash™ Unlock KeyPS3
# Gravity Rush™ 2PS4
# Gravity Rush™ RemasteredPS4
# Greg Hastings Paintball 2PS3
# GRID AutosportPS3
# Grim Fandango RemasteredPS4
# Grim Legends: The Forsaken BridePS4
# GUILTY GEAR Xrd -REVELATOR-PS4
# Hakuoki: Stories of the ShinsengumiPS3
# Hamilton's Great Adventure - VollversionPS3
# HamsterballPS3
# Hardware: RivalsPS4
# Heavy Rain™PS4
# Hohokum™PS3
# Hollow Knight: Voidheart-EditionPS4
# Hotel Transylvania 3 Monster Über BordPS4
# How to Survive: Storm Warning EditionPS4
# Hunter's Trophy 2 - AmericaPS3
# Hunter's Trophy 2 - AustraliaPS3
# Hustle Kings™PS3
# I am BreadPS4
# I, ZombiePS4
# ibb and obbPS3
# ICO™ Classics HDPS3
# In Space We BrawlPS3
# inFAMOUS™PS3
# inFAMOUS™ 2PS3
# inFAMOUS™: Festival of Blood – VollversionPS3
# Injustice: Götter unter uns - Ultimate EditionPS3
# Inside My RadioPS4
# Invizimals™: Das verlorene KönigreichPS3
# IroncastPS4
# Jetpack Joyride DeluxePS3
# Joe Dever’s Lone Wolf Console EditionPS4
# Judge Dee - The City God CasePS3
# Just Cause 4 - Standard EditionPS4
# KickBeat Special EditionPS4
# Killzone®PS3
# KILLZONE™ SHADOW FALLPS4
# KineticaPS2
# King OddballPS4
# Kingdom: New LandsPS4
# KNACK™PS4
# Knytt Underground™PS3
# Krinkle KrusherPS4
# Kromaia ΩPS4
# Kung Fu RabbitPS3
# Landwirtschafts-Simulator 15PS4
# Landwirtschafts-Simulator 17PS4
# Landwirtschafts-Simulator 19PS4
# LegasistaPS3
# Legend of Kay AnniversaryPS4
# LEGO® Batman™ 2: DC Super HeroesPS3
# LEGO® BATMAN™ 3:JENSEITS VON GOTHAMPS4
# LEGO® CITY UndercoverPS4
# LEGO® Harry Potter™ Die Jahre 5-7PS3
# LEGO® Pirates of the Caribbean PS3PS3
# LEGO® WorldsPS4
# Leo's FortunePS4
# Lernen mit den PooYoos - Teil 1PS3
# LIMBOPS4
# Linger in Shadows™PS3
# LittleBigPlanet™ 3PS4
# Lock's QuestPS4
# LocoRoco Cocoreccho!™PS3
# LocoRoco™ RemasteredPS4
# Lone Survivor: The Director's CutPS4
# Lords of the FallenPS4
# Lost Planet 3PS3
# Lost SeaPS4
# Lovely PlanetPS4
# LUMOPS4
# MachinariumPS3
# Mafia IIIPS4
# Magic OrbzPS3
# Magicka 2PS4
# MagusPS3
# Mahjong Tales: Ancient WisdomPS3
# Mantis Burn RacingPS4
# Mars: War logsPS3
# Marvel’s Spider-ManPS4
# MasterCubePS4
# MEGA MAN 10PS3
# MEGA MAN 9PS3
# Megadimension Neptunia VIIPS4
# Metal Gear Rising: RevengeancePS3
# Metal Gear Solid HD CollectionPS3
# Metal Gear Solid V: Ground ZeroesPS4
# Metal Gear Solid V: The Phantom PainPS4
# METAL SLUG 3PS4
# Metro 2033 ReduxPS4
# Metro: Last Light ReduxPS4
# Minutes™PS4
# Mirror's EdgePS3
# Mitsurugi Kamui HikaePS4
# Mittelerde™: Mordors Schatten™PS4
# Momonga Pinball AdventuresPS4
# Monkey Island™ 2 Special Edition: LeChuck's Revenge™PS3
# Monster Energy Supercross - The Official VideogamePS4
# Mordheim: City of the DamnedPS4
# MotoGP™15PS3
# MotoGP™17PS4
# Motorcycle ClubPS3
# MotorStorm® ApocalypsePS3
# MotorStorm® RC Komplett-EditionPS3
# Mount and Blade: WarbandPS4
# MudRunnerPS4
# MX vs ATV: AlivePS3
# MX vs. ATV Supercross EncorePS4
# MXGP - The Official Motocross VideogamePS3
# MXGP2 - The Official Motocross VideogamePS4
# MXGP3 - The Official Motocross VideogamePS4
# Mystery Chronicle: One Way HeroicsPS4
# NASCAR Heat 3PS4
# NAtURAL DOCtRINEPS4
# NBA 2K18PS4
# Need for Speed™ RivalsPS3
# Neon ChromePS4
# NeuroVoiderPS4
# NidhoggPS4
# Nightmares from the Deep 2: The Siren's CallPS4
# Nightmares from the Deep: The Cursed HeartPS4
# NiGHTS into dreams…PS3
# Nights of AzurePS4
# Nights of Azure 2: Bride of the New MoonPS4
# NINJA GAIDEN® SIGMA 2PS3
# Ninja Pizza GirlPS4
# No Time To ExplainPS4
# NOBUNAGA'S AMBITION: Sphere of InfluencePS3
# Nova-111PS3
# Numblast™PS3
# ObliteracersPS4
# Oddworld: Stranger's Wrath HD - PS3PS3
# OKAGE: Shadow KingPS2
# OlliOlli2: Welcome to OlliwoodPS4
# Omega QuintetPS4
# Order Up!!PS3
# Overcooked! 2PS4
# Overlord Gefährten des BösenPS4
# Painkiller - Hell and DamnationPS3
# Pang AdventuresPS4
# Papo and Yo Volle SpielPS3
# PAYDAY 2: CRIMEWAVE EDITION.PS4
# PharaonicPS4
# Phineas und Ferb quer durch die 2. DimensionPS3
# PidPS3
# Pillars of Eternity: Complete EditionPS4
# Pix the CatPS4
# Pixel Heroes: Byte and MagicPS4
# Pixel PiracyPS4
# PixelJunk™ Nom Nom GalaxyPS4
# PixelJunk™ Racers: Runde 2PS3
# PixelJunk™ ShooterPS3
# PixelJunk™ Shooter 2PS3
# PixelJunk™ Shooter UltimatePS4
# Piyotama™PS3
# Plague RoadPS4
# Planet Minigolf™PS3
# PONCHOPS4
# Pool NationPS3
# Port Royale 3PS3
# PreyPS4
# PrimalPS2
# ProteusPS3
# Pumped BMX +PS3
# Pure Hold'em World Poker ChampionshipPS4
# Pure PoolPS4
# Puzzle AgentPS3
# Puzzle Fighter HDPS3
# QUANTUM THEORYPS3
# R-Type DimensionsPS3
# Rad RodgersPS4
# Rag Doll Kung Fu™: Fists of PlasticPS3
# Ragnarok Odyssey ACEPS3
# Raiden IV: OverKillPS3
# Raiden V: Director's CutPS4
# Rainbow MoonPS4
# rain™PS3
# Rapala Fishing: Pro SeriesPS4
# Ratchet & Clank™: QForcePS3
# Ratchet and Clank™: A Crack In TimePS3
# Ratchet and Clank™: All 4 OnePS3
# Ratchet and Clank™: Nexus (PS3)PS3
# Ratchet and Clank™: Quest for BootyPS3
# RDR Undead NightmarePS3
# Real FarmPS4
# Realms Of Ancient WarPS3
# Rebel GalaxyPS4
# Red Dead RedemptionPS3
# Red FactionPS2
# Red Faction Guerrilla Re-Mars-teredPS4
# Red Faction IIPS2
# Red Johnson's Chronicles - Einer gegen allePS3
# Renegade Ops™PS3
# RESIDENT EVIL CODE: Veronica XPS3
# Resident Evil Operation Raccoon CityPS3
# Resident Evil: The Darkside ChroniclesPS3
# Resident Evil™ RevelationsPS3
# RESOGUN™PS3
# Retro/GradePS3
# ReusPS4
# Ricochet HDPS3
# RIDEPS3
# RIDE 3PS4
# Riff: Everyday Shooter™PS3
# Risen 3: Titan Lords - Enhanced EditionPS4
# RIVEPS4
# Rocket League®PS4
# Rocketbirds: Hardboiled ChickenPS3
# Rogue Galaxy™PS2
# Rogue StormersPS4
# Romance of The Three Kingdoms 13PS4
# Sacred CitadelPS3
# Saints Row 2PS3
# Saints Row IV: Re-ElectedPS4
# Saints Row: Gat out of HellPS4
# SAMURAI WARRIORS 4PS3
# Savage Moon™PS3
# SBCG4AP Episode 1: Homestar RuinerPS3
# SBCG4AP Episode 2: Strong Badia the FreePS3
# SBCG4AP Episode 3: Baddest of the BandsPS3
# Seasons after FallPS4
# Sébastien Loeb Rally EVOPS4
# Shadow Complex RemasteredPS4
# Shadow of the Beast™PS4
# Shadow of the Colossus™ Classics HDPS3
# Shadow of the Tomb RaiderPS4
# ShadwenPS4
# Shatter™PS3
# Sherlock Holmes : The Devil's DaughterPS4
# Shiness: The Lightning KingdomPS4
# Sine Mora EXPS4
# Skullgirls EncorePS3
# Sky Fighter™PS3
# Skydive: Proximity FlightPS3
# SkyScrappersPS4
# Slime-san: Superslime EditionPS4
# Sly Cooper™: Jagd durch die ZeitPS3
# Smash CarsPS3
# Snakeball™PS3
# Sniper Elite 3 ULTIMATE EDITIONPS4
# Sniper Elite 4PS4
# Sniper Elite V2PS3
# Sniper Ghost Warrior 2PS3
# Söldner-X: HimmelsstürmerPS3
# SOMAPS4
# Sonic AdventurePS3
# Sonic Adventure™ 2PS3
# Sonic CDPS3
# Sonic GenerationsPS3
# Sonic the FightersPS3
# SONIC THE HEDGEHOG 4 Episode IPS3
# Sonic the Hedgehog™ 4 Episode IIPS3
# Sonic UnleashedPS3
# Soul AxiomPS4
# Sound Shapes™PS4
# Space AcePS3
# Sparkle 2PS4
# Sparkle UnleashedPS4
# Spec Ops: The LinePS3
# SpelunkyPS3
# Split/Second: VelocityPS3
# Square HeroesPS4
# STAR WARS® JEDI STARFIGHTER™PS4
# STAR WARS® RACER REVENGE™PS2
# STAR WARS™ BOUNTY HUNTER™PS2
# Star Wars™ The Force Unleashed™ IIPS3
# Stardust Galaxy Warriors: Stellar ClimaxPS4
# Starhawk™PS3
# STARWHALPS3
# Stealth Inc 2: A Game of ClonesPS3
# Stealth Inc: Ultimate EditionPS4
# STEEPPS4
# Steredenn: Binary StarsPS4
# Stick it to the Man™PS4
# Stikbold! Ein Dodgeball-AbenteuerPS4
# STRIDERPS4
# Strike Suit Zero: Director's CutPS4
# Styx: Shards of DarknessPS4
# Super Exploding Zoo!PS4
# Super Hang-OnPS3
# Super Star WarsPS4
# Super Stardust HD™PS3
# Super Stardust™ UltraPS4
# Super Toy CarsPS4
# Surgeon Simulator: Anniversary EditionPS4
# SyberiaPS3
# Syberia 2PS3
# Tachyon ProjectPS4
# Tales from Space: Mutant Blobs AttackPS3
# Tearaway™ UnfoldedPS4
# Tennis in the FacePS4
# Terraria – PlayStation®4 EditionPS4
# TeslagradPS3
# TetraminosPS4
# The Awakened Fate UltimatumPS3
# The Book of Unwritten Tales 2PS3
# The Bug ButcherPS4
# The DwarvesPS4
# The Evil WithinPS4
# The Evil Within® 2PS4
# The Final StationPS4
# The Golf Club 2019 featuring PGA TOURPS4
# The Guided Fate Paradox Full GamePS3
# The Keeper of 4 ElementsPS4
# The King of Fighters XIIIPS3
# The Last GuyPS3
# The Last of Us™: Left Behind (Standalone)PS3
# The Last Tinker™: City of ColorsPS4
# The LEGO® Movie VideogamePS3
# The LEGO® NINJAGO® Movie VideogamePS4
# The Metronomicon: Slay the Dance FloorPS4
# The Raven - Legacy of a Master ThiefPS3
# The Raven RemasteredPS4
# The Secret of Monkey Island™: Special EditionPS3
# The Spectrum RetreatPS4
# The SurgePS4
# The SwindlePS3
# The Town of LightPS4
# The Treasures of Montezuma 4PS3
# The Unfinished Swan™PS3
# The Vanishing of Ethan CarterPS4
# The Witch and the Hundred KnightPS3
# This War of Mine: The Little OnesPS4
# Thomas Was AlonePS3
# Tiny Troopers Joint OpsPS3
# Titan Attacks!PS3
# Titan QuestPS4
# Toki Tori 2+PS4
# TOKYO JUNGLEPS3
# Tokyo Xanadu eX+PS4
# TOM CLANCY'S RAINBOW SIX SIEGEPS4
# Torment: Tides of NumeneraPS4
# Touhou: Scarlet CuriosityPS4
# Toukiden 2PS4
# Toukiden: KiwamiPS4
# Tour de France 2017PS4
# Toy Home™PS3
# Toybox TurbosPS3
# Trash Panic™PS3
# Tricky TowersPS4
# Trine – Das spielPS3
# TRINITY: Souls of Zill O'llPS3
# TRON RUN/rPS4
# Tropico 5PS4
# Truck RacerPS3
# Twisted Metal™PS3
# Ultra Street Fighter™ IVPS4
# UltratronPS3
# Uncharted 2: Among Thieves™ (Dateigröße: 19,5 GB)PS3
# Uncharted 3: Drake's Deception™PS3
# Until Dawn™PS4
# Urban Trial FreestylePS3
# Valentino Rossi The GamePS4
# VampyrPS4
# Vegas PartyPS4
# Velocity®2XPS4
# Velocity®UltraPS3
# VesselPS3
# Victor Vran Overkill EditionPS4
# Vikings - Wolves of MidgardPS4
# Virtua Fighter 2™PS3
# Virtua Fighter 5 Final ShowdownPS3
# Wakeboarding HD™PS3
# Warhammer: End Times - VermintidePS4
# WARRIORS ALL-STARSPS4
# WARRIORS OROCHI 3PS3
# Warriors: Legends of TroyPS3
# Wasteland™ 2: Director's CutPS4
# When Vikings Attack™PS3
# Whispering WillowsPS4
# Wild Arms 3PS2
# Wild Guns™ ReloadedPS4
# Wolfenstein: The New OrderPS4
# Wolfenstein: The Old BloodPS4
# Wolfenstein® II: The New Colossus™ (CUSA07379)PS4
# World to the WestPS4
# WRC 5 eSports EditionPS4
# WuppoPS4
# WWE 2K18PS4
# XCOM® 2PS4
# XCOM®: Enemy WithinPS3
# Yaiba: Ninja Gaiden ZPS3
# Yakuza 4PS3
# Yakuza 5PS3
# YamaYamaPS4
# Yesterday OriginsPS4
# Zack ZeroPS3
# Zeno Clash 2PS3
# ZigguratPS4
# Zombie Tycoon II: Brainhov's RevengePS3
# Zombie VikingsPS4
